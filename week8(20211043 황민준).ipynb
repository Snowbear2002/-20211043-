# %%
strVal='data science'
nVal=12345
fVal=1.2
lVal=['data', 'science']
dVal={'lecture' : 'data science'}
bVal=True

# %%
# 기본적인 주석

# %%
'''
이런 형태의 주석도 많이 사용
'''

# %%
strVal
# Out:
# 'data science'

# %%
nVal
# Out:
# 12345

# %%
fVal
# Out:
# 1.2

# %%
lVal
# Out:
# ['data', 'science']

# %%
dVal
# Out:
# {'lecture': 'data science'}

# %%
bVal
# Out:
# True

# %%
print('strVal : ', type(strVal))
print('nVal : ', type(nVal))
print('fVal : ', type(fVal))
print('lVal : ', type(lVal))
print('dVal : ', type(dVal))
print('bVal : ', type(bVal))
# Out:
# strVal :  <class 'str'>
# nVal :  <class 'int'>
# fVal :  <class 'float'>
# lVal :  <class 'list'>
# dVal :  <class 'dict'>
# bVal :  <class 'bool'>

# %%
nVal=16
fVal=3.14

# %%
print('10진수 표현 : ', nVal)
print('2진수 표현 : ', bin(nVal))
print('8진수 표현 : ', oct(nVal))
print('16진수 표현 : ', hex(nVal))
# Out:
# 10진수 표현 :  16
# 2진수 표현 :  0b10000
# 8진수 표현 :  0o20
# 16진수 표현 :  0x10

# %%
btVal = True
bfVal = False

# %%
btVal = TRUE
bfVal = FALSE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\3666532701.py in <module>
# ----> 1 btVal = TRUE
#       2 bfVal = FALSE
#
# NameError: name 'TRUE' is not defined

# %%
btVal = true
bfVal = false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\3033162801.py in <module>
# ----> 1 btVal = true
#       2 bfVal = false
#
# NameError: name 'true' is not defined

# %%
10==11
# Out:
# False

# %%
10!=11
# Out:
# True

# %%
10>=11
# Out:
# False

# %%
10<=11
# Out:
# True

# %%
10>11
# Out:
# False

# %%
10<11
# Out:
# True

# %%
nBig=100
nSmall=10

# %%
print(nBig == nSmall)
print(nBig != nSmall)
print(nBig >= nSmall)
print(nBig <= nSmall)
print(nBig > nSmall)
print(nBig < nSmall)
# Out:
# False
# True
# True
# False
# True
# False

# %%
print(nBig =< nSmall)
# Out:
#   File "C:\Users\mait5\AppData\Local\Temp\ipykernel_1460\2189819302.py", line 1
#     print(nBig =< nSmall)
#                 ^
# SyntaxError: invalid syntax

# %%
print(nBig => nSmall)
# Out:
#   File "C:\Users\mait5\AppData\Local\Temp\ipykernel_1460\4185127180.py", line 1
#     print(nBig => nSmall)
#                 ^
# SyntaxError: invalid syntax

# %%
strData = 'data'
strSci = "Science"

# %%
strLecture = strData + strSci

# %%
strLecture
# Out:
# 'dataScience'

# %%
strLecture = strData +" "+ strSci
strLecture
# Out:
# 'data Science'

# %%
strLecture.split()
# Out:
# ['data', 'Science']

# %%
lSeperate = strLecture.split()

# %%
type(lSeperate)
# Out:
# list

# %%
strHello = "안녕하세요. 반갑습니다."

# %%
strHello.find("반갑")
# Out:
# 7

# %%
strHello.find("hello")
# Out:
# -1

# %%
"반갑" in strHello
# Out:
# True

# %%
strHello.replace('.', '?')
# Out:
# '안녕하세요? 반갑습니다?'

# %%
strHello.replace('.', '?')
strHello.replace("하세요", "하셔유")
# Out:
# '안녕하셔유. 반갑습니다.'

# %%
strHello
# Out:
# '안녕하세요. 반갑습니다.'

# %%
strNewHello = strHello.replace('.', '?')
strNewHello = strNewHello.replace("하세요", "하셔유")
strNewHello
# Out:
# '안녕하셔유? 반갑습니다?'

# %%
strHello.strip('반갑습니다.')
# Out:
# '안녕하세요. '

# %%
strHello
# Out:
# '안녕하세요. 반갑습니다.'

# %%
lnData = [1,2,3,4,5]
print(lnData)
print('type : ', type(lnData))
# Out:
# [1, 2, 3, 4, 5]
# type :  <class 'list'>

# %%
print(lnData[0])
print(lnData[3])
# Out:
# 1
# 4

# %%
lnData[0] = lnData[4]
print(lnData)
# Out:
# [5, 2, 3, 4, 5]

# %%
print(lnData[2:4])
# Out:
# [3, 4]

# %%
lnData = [1,2,3,4,5]
lstrData=['a', 'b', 'c']
lnData + lstrData
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c']

# %%
lnData.append(10)
lnData
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
lnData.insert(0, 'python')
lnData
# Out:
# ['python', 1, 2, 3, 4, 5, 10]

# %%
lnData.remove('python')
lnData
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
del lnData[5]
lnData
# Out:
# [1, 2, 3, 4, 5]

# %%
lnData.pop(0)
lnData
# Out:
# [2, 3, 4, 5]

# %%
lnData.pop()
lnData
# Out:
# [2, 3, 4]

# %%
lnData.clear()
lnData
# Out:
# []

# %%
tVal = ("사과", "딸기", "바나나", "토마토", "키위")

print(tVal)
print(type(tVal))
# Out:
# ('사과', '딸기', '바나나', '토마토', '키위')
# <class 'tuple'>

# %%
tVal[0] = "포도"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\1425330867.py in <module>
# ----> 1 tVal[0] = "포도"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tData = ( 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)
tData.count(1)
# Out:
# 3

# %%
len(tVal)
# Out:
# 5

# %%
len(tData)
# Out:
# 11

# %%
print(tData[2:5])
# Out:
# (3, 1, 2)

# %%
tTuple = tVal+ tData
print(tTuple)
# Out:
# ('사과', '딸기', '바나나', '토마토', '키위', 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData * 2
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7, 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
tData2 = tData * 2
print(tData2)
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7, 1, 2, 3, 1, 2, 3, 4, 5, 1, 2, 7)

# %%
print("tVal memory = ", hex(id(tVal)))
tVal = tVal * 2
print("tVal memory = ", hex(id(tVal)))
print(tVal)
# Out:
# tVal memory =  0x22a8bd7e0e0
# tVal memory =  0x22a8be30040
# ('사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위')

# %%
print("tVal memory = ", hex(id(tVal)))
tVal = tVal + tVal
print("tVal memory = ", hex(id(tVal)))
print(tVal)
# Out:
# tVal memory =  0x22a8be30040
# tVal memory =  0x22a8be215f0
# ('사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위', '사과', '딸기', '바나나', '토마토', '키위')

# %%
sVal = {1, 2, 3, 4, 5}
print(sVal)
print(type(sVal))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
sVal[1:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\468339363.py in <module>
# ----> 1 sVal[1:2]
#
# TypeError: 'set' object is not subscriptable

# %%
sVal.add(100)
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100}

# %%
sVal.update([200, 300])
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100, 200, 300}

# %%
sVal.remove(200)
print(sVal)
# Out:
# {1, 2, 3, 4, 5, 100, 300}

# %%
sVal.clear()
print(sVal)
# Out:
# set()

# %%
sVal = {100, 200, 300, 400, 500}
sData = {"a", "b", "c", "c", 100, 300}
print(sVal)
print(sData)
# Out:
# {400, 100, 500, 200, 300}
# {'a', 100, 'b', 'c', 300}

# %%
sVal.intersection(sData)
# Out:
# {100, 300}

# %%
sVal.difference(sData)
# Out:
# {200, 400, 500}

# %%
sVal - sData
# Out:
# {200, 400, 500}

# %%
sVal.union(sData)
# Out:
# {100, 200, 300, 400, 500, 'a', 'b', 'c'}

# %%
sVal + sData
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\3583393361.py in <module>
# ----> 1 sVal + sData
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
sVal.symmetric_difference(sData)
# Out:
# {200, 400, 500, 'a', 'b', 'c'}

# %%
dVal = {
    'name' : '이컴공',
    'email' : 'computer@hoseo.edu',
    'address' : '충남 아산시'
}
print(dVal)
print(type(dVal))
# Out:
# {'name': '이컴공', 'email': 'computer@hoseo.edu', 'address': '충남 아산시'}
# <class 'dict'>

# %%
dData = {
    "사과" : 300, 
    "포도" : 200, 
    "배" : 500,
    "키위" : 100
}

# %%
print(dData["배"])
# Out:
# 500

# %%
dData.get("배")
# Out:
# 500

# %%
dData["딸기"] = 100
print(dData)
# Out:
# {'사과': 300, '포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
dData.pop("사과")
# Out:
# 300

# %%
dData
# Out:
# {'포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
dData.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\2765138924.py in <module>
# ----> 1 dData.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
sorted(dData)
# Out:
# ['딸기', '배', '키위', '포도']

# %%
sorted(dData.values())
# Out:
# [100, 100, 200, 500]

# %%
dData
# Out:
# {'포도': 200, '배': 500, '키위': 100, '딸기': 100}

# %%
def f(x):
  return x + 10

# %%
f(2)
# Out:
# 12

# %%
strText = input("아무 문장이나 입력하세요 : ")
print(strText)
# Out:
# 아무 문장이나 입력하세요 : 테스트
# 테스트

# %%
flVal = [1.0, 2.0, 3.14, 4.2, 5.1]

# %%
arVal = [flVal, flVal, flVal]
arVal
# Out:
# [[1.0, 2.0, 3.14, 4.2, 5.1],
#  [1.0, 2.0, 3.14, 4.2, 5.1],
#  [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
arVal[0]
# Out:
# [1.0, 2.0, 3.14, 4.2, 5.1]

# %%
arVal[1]
# Out:
# [1.0, 2.0, 3.14, 4.2, 5.1]

# %%
arVal[1][2]
# Out:
# 3.14

# %%
arVal[0] = 'python'
arVal
# Out:
# ['python', [1.0, 2.0, 3.14, 4.2, 5.1], [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
arVal[0][2]
# Out:
# 't'

# %%
arVal[0] = 'python programming'
arVal
# Out:
# ['python programming', [1.0, 2.0, 3.14, 4.2, 5.1], [1.0, 2.0, 3.14, 4.2, 5.1]]

# %%
import numpy as np
arData = np.array([1.0, 2.0, 3.14, 4.2, 5.1])
arData
# Out:
# array([1.  , 2.  , 3.14, 4.2 , 5.1 ])

# %%
arData.sum()
# Out:
# 15.44

# %%
arVal.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\2999335311.py in <module>
# ----> 1 arVal.sum()
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
print(type(arVal))
print(type(arData))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
arData.std()
# Out:
# 1.4717934637713266

# %%
arData.cumsum()
# Out:
# array([ 1.  ,  3.  ,  6.14, 10.34, 15.44])

# %%
arData * 2
# Out:
# array([ 2.  ,  4.  ,  6.28,  8.4 , 10.2 ])

# %%
arData ** 2
# Out:
# array([ 1.    ,  4.    ,  9.8596, 17.64  , 26.01  ])

# %%
np.sqrt(arData)
# Out:
# array([1.        , 1.41421356, 1.77200451, 2.04939015, 2.25831796])

# %%
arVal = np.array([arData, arData ** 2])
arVal
# Out:
# array([[ 1.    ,  2.    ,  3.14  ,  4.2   ,  5.1   ],
#        [ 1.    ,  4.    ,  9.8596, 17.64  , 26.01  ]])

# %%
arVal.sum(axis=0)
# Out:
# array([ 2.    ,  6.    , 12.9996, 21.84  , 31.11  ])

# %%
arVal.sum(axis=1)
# Out:
# array([15.44  , 58.5096])

# %%
np.array([[0,0,0],[0,0,0]])
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
arZero = np.zeros((2,3), dtype = 'i') 
arZero
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]], dtype=int32)

# %%
import pandas as pd

pandas_series = pd.Series([30, 20, 10], index=['국어', '영어', '수학'])
print(type(pandas_series))
pandas_series
# Out:
# <class 'pandas.core.series.Series'>
# 국어    30
# 영어    20
# 수학    10
# dtype: int64

# %%
pandas_series[1:]
# Out:
# 영어    20
# 수학    10
# dtype: int64

# %%
pandas_series[0]
# Out:
# 30

# %%
pandas_series[0][1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\3046292380.py in <module>
# ----> 1 pandas_series[0][1]
#
# IndexError: invalid index to scalar variable.

# %%
df = pd.DataFrame([30,20,10], columns=['score'], index=['국어', '영어', '수학'])
df
# Out:
#     score
# 국어     30
# 영어     20
# 수학     10

# %%
df.index
# Out:
# Index(['국어', '영어', '수학'], dtype='object')

# %%
df.columns
# Out:
# Index(['score'], dtype='object')

# %%
df.loc['국어']
# Out:
# score    30
# Name: 국어, dtype: int64

# %%
df.sum()
# Out:
# score    60
# dtype: int64

# %%
df.score ** 2
# Out:
# 국어    900
# 영어    400
# 수학    100
# Name: score, dtype: int64

# %%
df['score2'] = (50, 50, 50)
df
# Out:
#     score  score2
# 국어     30      50
# 영어     20      50
# 수학     10      50

# %%
df['score2'] = pd.DataFrame([90,90,90], index=['국어', '영어', '수학'])
df
# Out:
#     score  score2
# 국어     30      90
# 영어     20      90
# 수학     10      90

# %%
del df['score']

# %%
df['score2'] = (90, 90, 90, 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1460\737594061.py in <module>
# ----> 1 df['score2'] = (90, 90, 90, 100)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (4) does not match length of index (3)

# %%
df['score2'] = pd.DataFrame([90, 90, 90, 100], index=['국어', '영어', '수학', '윤리'])
df
# Out:
#     score2
# 국어      90
# 영어      90
# 수학      90

# %%
df1 = pd.DataFrame([1, 2, 3], columns = ['A'])
df2 = pd.DataFrame([10, 11, 12, 13], columns = ['B'])

df = df1.join(df2, how='outer')
df
# Out:
#      A   B
# 0  1.0  10
# 1  2.0  11
# 2  3.0  12
# 3  NaN  13

# %%
df_inner = df1.join(df2, how='inner')
df_inner
# Out:
#    A   B
# 0  1  10
# 1  2  11
# 2  3  12

# %%
df = pd.DataFrame(np.random.randn(5,5))
df.columns = ['A', 'B', 'C', 'D', 'E']

df
# Out:
#           A         B         C         D         E
# 0  0.790739  0.192380 -0.066090  0.540101 -0.957173
# 1  2.064086  0.131831 -0.016898  1.660457  1.385610
# 2  1.214803 -1.225968  0.833614 -1.740997  1.912344
# 3  0.050795  1.467298 -1.174180  0.888518 -0.801092
# 4  1.416340 -1.443623  0.081584 -0.270913 -0.254288

# %%
df.max()
# Out:
# A    2.064086
# B    1.467298
# C    0.833614
# D    1.660457
# E    1.912344
# dtype: float64

# %%
df.min()
# Out:
# A    0.050795
# B   -1.443623
# C   -1.174180
# D   -1.740997
# E   -0.957173
# dtype: float64

# %%
df.mean()
# Out:
# A    1.107353
# B   -0.175616
# C   -0.068394
# D    0.215433
# E    0.257080
# dtype: float64

# %%
df.std()
# Out:
# A    0.748150
# B    1.187454
# C    0.717902
# D    1.295251
# E    1.310450
# dtype: float64

# %%
df.cumsum()
# Out:
#           A         B         C         D         E
# 0  0.790739  0.192380 -0.066090  0.540101 -0.957173
# 1  2.854825  0.324211 -0.082987  2.200559  0.428437
# 2  4.069628 -0.901756  0.750627  0.459561  2.340781
# 3  4.120423  0.565542 -0.423553  1.348079  1.539689
# 4  5.536763 -0.878081 -0.341970  1.077166  1.285401

# %%
df.describe()
# Out:
#               A         B         C         D         E
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   1.107353 -0.175616 -0.068394  0.215433  0.257080
# std    0.748150  1.187454  0.717902  1.295251  1.310450
# min    0.050795 -1.443623 -1.174180 -1.740997 -0.957173
# 25%    0.790739 -1.225968 -0.066090 -0.270913 -0.801092
# 50%    1.214803  0.131831 -0.016898  0.540101 -0.254288
# 75%    1.416340  0.192380  0.081584  0.888518  1.385610
# max    2.064086  1.467298  0.833614  1.660457  1.912344

# %%
df['division'] = ['X', 'Y', 'X', 'Y', 'Z']
df
# Out:
#           A         B         C         D         E division
# 0  0.790739  0.192380 -0.066090  0.540101 -0.957173        X
# 1  2.064086  0.131831 -0.016898  1.660457  1.385610        Y
# 2  1.214803 -1.225968  0.833614 -1.740997  1.912344        X
# 3  0.050795  1.467298 -1.174180  0.888518 -0.801092        Y
# 4  1.416340 -1.443623  0.081584 -0.270913 -0.254288        Z

# %%
df.groupby(['division']).mean()
# Out:
#                  A         B         C         D         E
# division
# X         1.002771 -0.516794  0.383762 -0.600448  0.477586
# Y         1.057441  0.799565 -0.595539  1.274488  0.292259
# Z         1.416340 -1.443623  0.081584 -0.270913 -0.254288

# %%
import pandas as pd

sr = pd.Series([100, 200, 300, 400])
sr.index = ['A', 'B', 'O', 'AB']
sr
# Out:
# A     100
# B     200
# O     300
# AB    400
# dtype: int64

# %%
sr1 = pd.Series([10, 20, 30])
sr1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({'키':[170, 180, 175], '몸무게':[65, 78, 70]})
df.index = ['스파이더맨', '닥터스트레인지', '아이언맨']
df
# Out:
#            키  몸무게
# 스파이더맨    170   65
# 닥터스트레인지  180   78
# 아이언맨     175   70

# %%
df = pd.read_excel(r'C:\Users\mait5\OneDrive\문서\scores.xlsx')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    petre  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.head()
# Out:
#        이름     국어   영어     수학
# 0    tony  100.0   90   95.0
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   petre  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
df.tail()
# Out:
#         이름     국어   영어    수학
# 5      tor   70.0   75  65.0
# 6    bruce   80.0   90  55.0
# 7     thor   50.0   60   NaN
# 8  steaven  100.0  100  90.0
# 9    wanda   90.0   95  70.0

# %%
df.sample(3)
# Out:
#         이름     국어   영어     수학
# 2   vision   95.0  100  100.0
# 5      tor   70.0   75   65.0
# 8  steaven  100.0  100   90.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     object
#  1   국어      9 non-null      float64
#  2   영어      10 non-null     int64
#  3   수학      9 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df.shape
# Out:
# (10, 4)

# %%
len(df)
# Out:
# 10

# %%
df.isnull().sum()
# Out:
# 이름    0
# 국어    1
# 영어    0
# 수학    1
# dtype: int64

# %%
df_dropna = df.dropna()
df_dropna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    petre  100.0  100  100.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df_fillna = df.fillna(50)
df_fillna
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    petre  100.0  100  100.0
# 4    scott   50.0   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60   50.0
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.describe()
# Out:
#                국어          영어          수학
# count    9.000000   10.000000    9.000000
# mean    86.111111   82.500000   78.888889
# std     16.914819   21.114766   17.638342
# min     50.000000   35.000000   55.000000
# 25%     80.000000   76.250000   65.000000
# 50%     90.000000   90.000000   75.000000
# 75%    100.000000   98.750000   95.000000
# max    100.000000  100.000000  100.000000

# %%
df['국어'].sum()
# Out:
# 775.0

# %%
df.value_counts('영어')
# Out:
# 영어
# 100    3
# 90     2
# 35     1
# 60     1
# 75     1
# 80     1
# 95     1
# dtype: int64

# %%
df['국어']
# Out:
# 0    100.0
# 1     90.0
# 2     95.0
# 3    100.0
# 4      NaN
# 5     70.0
# 6     80.0
# 7     50.0
# 8    100.0
# 9     90.0
# Name: 국어, dtype: float64

# %%
df[['국어', '영어']]
# Out:
#       국어   영어
# 0  100.0   90
# 1   90.0   80
# 2   95.0  100
# 3  100.0  100
# 4    NaN   35
# 5   70.0   75
# 6   80.0   90
# 7   50.0   60
# 8  100.0  100
# 9   90.0   95

# %%
df.loc[1]
# Out:
# 이름     sam
# 국어    90.0
# 영어      80
# 수학    75.0
# Name: 1, dtype: object

# %%
df.loc[[1,2,3]]
# Out:
#        이름     국어   영어     수학
# 1     sam   90.0   80   75.0
# 2  vision   95.0  100  100.0
# 3   petre  100.0  100  100.0

# %%
df.iloc[2]
# Out:
# 이름    vision
# 국어      95.0
# 영어       100
# 수학     100.0
# Name: 2, dtype: object

# %%
df.iloc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   petre  100.0  100  100.0
# 4   scott    NaN   35   60.0

# %%
df.loc[2:5]
# Out:
#        이름     국어   영어     수학
# 2  vision   95.0  100  100.0
# 3   petre  100.0  100  100.0
# 4   scott    NaN   35   60.0
# 5     tor   70.0   75   65.0

# %%
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    petre  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
df.iloc[1,3]
# Out:
# 75.0

# %%
df.iloc[1:3, 1:3]
# Out:
#      국어   영어
# 1  90.0   80
# 2  95.0  100

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
# matplotlib 한글폰트 지정
plt.rc('font', family='NanumBarunGothic')

# - 기호 깨짐 오류 방지
plt.rc('axes', unicode_minus = False)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.plot(x,y)
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.plot(x,y, color="blue", marker = 'o', linestyle = ':')
plt.title('월별 평균 온도', fontsize=15)
plt.ylabel('온도(도)')
plt.grid(linestyle = ':')
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
aVal = np.random.standard_normal(40)
aVal
# Out:
# array([-0.32654402, -0.13447502,  0.18501793, -0.53581583,  0.32632591,
#         0.56456835,  0.17200416,  0.43224024,  0.64567631, -1.6243219 ,
#         0.25171032,  0.0209165 ,  0.53001112, -0.06122871,  1.11079268,
#         0.55809265,  0.02393825, -0.0163359 , -0.60432813,  1.62586835,
#        -0.49814935, -0.88606009, -0.1306548 , -1.27358007,  1.06129211,
#        -2.25231093, -0.46815059,  0.29204582,  0.32289704,  0.86366394,
#        -0.45233005,  2.16290103, -1.95682254,  0.62437535, -1.06539493,
#         0.83820984,  0.09972896, -0.10764863, -0.16582381, -0.60400223])

# %%
type(aVal)
# Out:
# numpy.ndarray

# %%
index = range(len(aVal))
plt.plot(index, aVal)

# x축, y축의 범위 설정
plt.xlim(0, 20)
plt.ylim(np.min(aVal) -1, np.max(aVal) + 1)
plt.show()

# %%
type(index)
# Out:
# range

# %%
plt.figure(figsize=(7,4))
plt.plot(aVal.cumsum(), 'b', lw= 1.5)
plt.plot(aVal.cumsum(), 'ro')
plt.xlabel('index')
plt.ylabel('aVal')
plt.title('Line Plot')
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
value = np.random.standard_normal((30, 2))
value
# Out:
# array([[-0.12386877, -0.2862626 ],
#        [-0.45899894,  0.86472664],
#        [ 0.50656317, -0.11003041],
#        [-0.31055589,  0.49452075],
#        [ 0.48139477, -0.372915  ],
#        [-1.57361066,  0.83448022],
#        [ 0.22880306, -0.22242558],
#        [ 0.26906099,  0.5106295 ],
#        [ 1.17391108, -0.33064217],
#        [-0.73627238,  0.86529634],
#        [ 0.32070304, -1.64833433],
#        [ 0.12734033,  0.09013786],
#        [ 0.3422322 ,  0.82442192],
#        [ 2.04098845, -1.58442754],
#        [-0.7049057 ,  0.27890486],
#        [-0.31547819, -0.38090375],
#        [-0.86243261,  0.22518446],
#        [ 0.14654249,  1.15411435],
#        [-0.70023713, -1.06651019],
#        [-0.81799746, -1.06432074],
#        [-2.27129935,  1.15003958],
#        [-2.74459592,  0.60484957],
#        [ 0.11565161, -1.91448955],
#        [ 0.42998568, -1.30377509],
#        [-1.54302933, -0.27121809],
#        [ 0.97060055, -0.54789065],
#        [ 1.08809773, -1.1765748 ],
#        [-1.58644675,  1.19973291],
#        [ 0.10655519,  0.22335402],
#        [-0.00396847, -0.42447477]])

# %%
value[0]
# Out:
# array([-0.12386877, -0.2862626 ])

# %%
plt.figure(figsize=(10,4))
plt.plot(value[:,0], lw= 1.5)
plt.plot(value[:,1], lw= 1.5)
plt.plot(value, 'ro')
plt.grid(True)
# plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('Line Plot')
# Out:
# Text(0.5, 1.0, 'Line Plot')

# %%
plt.figure(figsize=(10,5))
plt.subplot(211)
plt.plot(value[:,0], lw = 1.5, label = '1st')
plt.plot(value[:,0], 'ro')
plt.grid(True)
plt.legend(loc = 0)
plt.ylabel("value")
plt.title('Line Plot 3')
# 2번째
plt.subplot(212)
plt.plot(value[:,1], 'g', lw = 1.5, label = '2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
plt.figure(figsize=(13,5))
plt.subplot(231)
plt.plot(value[:,0], lw= 1.5, label = '1st')
plt.plot(value[:,0], 'co')
plt.grid(True)
plt.legend(loc=0)
plt.ylabel('value')
plt.title('Line Plot 3')
# 2번째
plt.subplot(232)
plt.plot(value[:,0], 'g-.', lw=1.5, label='1st')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 3번째
plt.subplot(233)
plt.plot(value[:,0], 'g', lw=1.5, label='1st')
plt.plot(value[:,0], 'bD')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 4번째
plt.subplot(234)
plt.plot(value[:,1], '*', lw=1.5, label='2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 5번째
plt.subplot(235)
plt.plot(value[:,1], 'b', lw=1.5, label='2nd')
plt.plot(value[:,1], 'ms')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# 6번째
plt.subplot(236)
plt.plot(value[:,1], 'r--', lw=1.5, label='2nd')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
# Out:
# Text(0, 0.5, 'value')

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.bar(x,y)
plt.show()
# Out:
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.barh(x,y)
plt.show()
# Out:
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# x측
x = ['1월', '2월', '3월', '4월', '5월']
y = [7, 10, 17, 20, 23]

# 그래프
plt.bar(x,y, color="orange", width = 0.5, edgecolor = 'black', hatch = '/')
plt.title('월별 평균 온도', fontsize=15)
plt.ylabel('온도(도)')
plt.grid(linestyle = ':', axis = 'y')
plt.show()
# Out:
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# pandas를 import
import pandas as pd

# score.csv 파일 일기
df = pd.read_excel(r'C:\Users\mait5\OneDrive\문서\scores.xlsx')
df
# Out:
#         이름     국어   영어     수학
# 0     tony  100.0   90   95.0
# 1      sam   90.0   80   75.0
# 2   vision   95.0  100  100.0
# 3    petre  100.0  100  100.0
# 4    scott    NaN   35   60.0
# 5      tor   70.0   75   65.0
# 6    bruce   80.0   90   55.0
# 7     thor   50.0   60    NaN
# 8  steaven  100.0  100   90.0
# 9    wanda   90.0   95   70.0

# %%
x = df['이름']
y_kor = df['국어']

plt.bar(x, y_kor)
plt.show()

# %%
x = df['이름']
y_kor = df['국어']
y_eng = df['영어']

# 중심을 기준으로 왼쪽/오른쪽에 그래프를 구성
plt.bar(x, y_kor, width = -0.4, align = 'edge', label = '국어')
plt.bar(x, y_eng, width = 0.4, align = 'edge', label = '영어')
plt.title('국어/영어 점수 비교', fontsize = 15)
plt.ylabel('점수')

# 범례
plt.legend() 
plt.show()
# Out:
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44397 (\N{HANGUL SYLLABLE GUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50612 (\N{HANGUL SYLLABLE EO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mait5\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
value = np.random.standard_normal((500,2))
plt.plot(value[:,0], value[:,1], 'ro')
plt.grid(False)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 1')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 1')

# %%
plt.figure(figsize=(7,5))
plt.scatter(value[:,0], value[:,1], marker='o')
plt.grid(True)
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 2')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 2')

# %%
color = np.random.randint(0,10,len(value))

plt.figure(figsize=(10,5))
plt.scatter(value[:,0], value[:,1], c=color, marker = 'o')
plt.colorbar()
plt.xlabel('value 1')
plt.ylabel('value 2')
plt.title('Scatter Plot 3')
# Out:
# Text(0.5, 1.0, 'Scatter Plot 3')

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
x = df['total_bill']
y = df['tip']

sns.scatterplot(x,y)
# Out:
# C:\Users\mait5\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x="day", y = "tip", hue="sex", data=df, palette="muted")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline    

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.pairplot(iris)
plt.title("Iris Data Analysis")
# Out:
# Text(0.5, 1.0, 'Iris Data Analysis')

# %%
sns.pairplot(iris, hue="species", diag_kind='kde')

# %%
sns.boxplot(x='species', y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x='species', y="petal_width", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_width'>

# %%
iris.boxplot(by="species", figsize=(16,8))
# Out:
# array([[<AxesSubplot:title={'center':'petal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'petal_width'}, xlabel='[species]'>],
#        [<AxesSubplot:title={'center':'sepal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)
